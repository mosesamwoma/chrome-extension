# %%
import sys
import os
sys.path.append(os.getcwd())

# %%
import sys
import os

# 1. Force Python to look in the current folder for the 'scrapers' folder
sys.path.append(os.getcwd())

# 2. Import your code
from scrapers.real_estate.scrape_all_areas import scrape_all_areas

# 3. Your list of areas
areas = [
    "westlands", "parklands", "utawala", "rongai", 
    "kilimani", "karen", "langata", "nairobi-cbd", 
    "embakasi", "gikomba"
]

# 4. Run it
if __name__ == "__main__":
    df = scrape_all_areas(areas, pages=5)
    display(df.head()) # Shows the first 5 rows in your notebook
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 8
#       5 sys.path.append(os.getcwd())
#       7 # 2. Import your code
# ----> 8 from scrapers.real_estate.scrape_all_areas import scrape_all_areas
#      10 # 3. Your list of areas
#      11 areas = [
#      12     "westlands", "parklands", "utawala", "rongai",
#      13     "kilimani", "karen", "langata", "nairobi-cbd",
#      14     "embakasi", "gikomba"
#      15 ]
#
# ModuleNotFoundError: No module named 'scrapers'
