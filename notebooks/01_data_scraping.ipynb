# %%
from scraper.main_scraper import scrape_all_areas

# List of Nairobi neighborhoods
areas = [
    "westlands",
    "parklands",
    "utawala",
    "rongai",
    "kilimani",
    "karen",
    "langata",
    "nairobi-cbd",
    "embakasi",
    "gikomba"
]

# Scrape 5 pages per area (adjust as needed)
scrape_all_areas(areas, pages=5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from scraper.main_scraper import scrape_all_areas
#       3 # List of Nairobi neighborhoods
#       4 areas = [
#       5     "westlands",
#       6     "parklands",
#    (...)     14     "gikomba"
#      15 ]
#
# ModuleNotFoundError: No module named 'scraper'
